# %% [markdown]
# # Big Data CW2: Project
# # Thailand Mobility and Covid Case Study

# %% [markdown]
# ### 1. Import Data and Read Data from CSV files
#
# #### Mobility Data: df_mobility, limiting to only required columns
# #### Covid-19 Data:df_covid, limiting to only required columns

# %%
### import packages and set directory of where data is located
import pandas as pd
#always change pandas float display format to 2 decimal points
pd.options.display.float_format = '{:,.2f}'.format
pd.set_option('mode.chained_assignment', None)
import numpy as np
import datetime as dt
import seaborn
import matplotlib
import os
import matplotlib.pyplot as plt
import matplotlib.dates as md
os.getcwd()
path=r"C:\Users\neetm\Desktop\CW Big Data 28 April"
os.chdir(path)

# %%
### specify columns needed for mobility data and import csv to avoid low memory from high columns
col_mob = ['country_region_code', 'country_region','date',
       'retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline']
df_mobility=pd.read_csv("Global_Mobility_Report.csv",usecols=col_mob)
print(len(df_mobility))
display(df_mobility.head())
# Out:
# 9503416
#   country_region_code        country_region        date  \
# 0                  AE  United Arab Emirates  2020-02-15
# 1                  AE  United Arab Emirates  2020-02-16
# 2                  AE  United Arab Emirates  2020-02-17
# 3                  AE  United Arab Emirates  2020-02-18
# 4                  AE  United Arab Emirates  2020-02-19
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                               0.00
# 1                                               1.00
# 2                                              -1.00
# 3                                              -2.00
# 4                                              -2.00
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                               4.00
# 1                                               4.00
# 2                                               1.00
# 3                                               1.00
# 4                                               0.00
#
#    parks_percent_change_from_baseline  \
# 0                                5.00
# 1                                4.00
# 2                                5.00
# 3                                5.00
# 4                                4.00
#
#    transit_stations_percent_change_from_baseline  \
# 0                                           0.00
# 1                                           1.00
# 2                                           1.00
# 3                                           0.00
# 4                                          -1.00
#
#    workplaces_percent_change_from_baseline  \
# 0                                     2.00
# 1                                     2.00
# 2                                     2.00
# 3                                     2.00
# 4                                     2.00
#
#    residential_percent_change_from_baseline
# 0                                      1.00
# 1                                      1.00
# 2                                      1.00
# 3                                      1.00
# 4                                      1.00

# %%
### specify columns needed for covid data and import csv to avoid low memory from high columns
col_cov = ['continent', 'location', 'date',"new_cases", "new_deaths","people_vaccinated","people_fully_vaccinated"]
df_covid=pd.read_csv("owid-covid-data.csv",usecols=col_cov)
print(df_covid.shape)
display (df_covid.head())
# Out:
# (179205, 7)
#   continent     location        date  new_cases  new_deaths  \
# 0      Asia  Afghanistan  2020-02-24       5.00         NaN
# 1      Asia  Afghanistan  2020-02-25       0.00         NaN
# 2      Asia  Afghanistan  2020-02-26       0.00         NaN
# 3      Asia  Afghanistan  2020-02-27       0.00         NaN
# 4      Asia  Afghanistan  2020-02-28       0.00         NaN
#
#    people_vaccinated  people_fully_vaccinated
# 0                NaN                      NaN
# 1                NaN                      NaN
# 2                NaN                      NaN
# 3                NaN                      NaN
# 4                NaN                      NaN

# %%
#filter dataframe and create new dataframe for both mobility and covid data sets: focus Thailand

df_th_mob = df_mobility.loc[(df_mobility['country_region'] == 'Thailand')] #filter only Thailand country create new dataframe df_th_mob
df_th_cov = df_covid.loc[(df_covid['location'] == 'Thailand')] #filter only Thailand country create new dataframe df_th_cov

# %%
### Data cleaning
### Change date format
df_th_mob.loc[:,'date'] = pd.to_datetime(df_th_mob['date'])
df_th_cov.loc[:,'date'] = pd.to_datetime(df_th_cov['date'])
### fill na = 0 for required columns
df_th_mob[['retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline']] = df_th_mob[['retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline']].fillna(value=0)
df_th_cov[['new_cases', 'new_deaths', 'people_vaccinated',
       'people_fully_vaccinated']] = df_th_cov[['new_cases', 'new_deaths', 'people_vaccinated',
       'people_fully_vaccinated']].fillna(value=0)

# %%
#display df_th_mob - display thailand mobility data
print(df_th_mob.shape)
display(df_th_mob.head())
display(df_th_mob.describe())
# Out:
# (789, 9)
#         country_region_code country_region       date  \
# 6882943                  TH       Thailand 2020-02-15
# 6882944                  TH       Thailand 2020-02-16
# 6882945                  TH       Thailand 2020-02-17
# 6882946                  TH       Thailand 2020-02-18
# 6882947                  TH       Thailand 2020-02-19
#
#          retail_and_recreation_percent_change_from_baseline  \
# 6882943                                              -3.00
# 6882944                                              -3.00
# 6882945                                              -3.00
# 6882946                                              -3.00
# 6882947                                              -4.00
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 6882943                                               1.00
# 6882944                                               2.00
# 6882945                                               1.00
# 6882946                                               0.00
# 6882947                                              -3.00
#
#          parks_percent_change_from_baseline  \
# 6882943                               -8.00
# 6882944                               -5.00
# 6882945                               -3.00
# 6882946                               -5.00
# 6882947                               -3.00
#
#          transit_stations_percent_change_from_baseline  \
# 6882943                                          -2.00
# 6882944                                          -4.00
# 6882945                                          -4.00
# 6882946                                          -6.00
# 6882947                                          -6.00
#
#          workplaces_percent_change_from_baseline  \
# 6882943                                     7.00
# 6882944                                     2.00
# 6882945                                     2.00
# 6882946                                     0.00
# 6882947                                     0.00
#
#          residential_percent_change_from_baseline
# 6882943                                      1.00
# 6882944                                      2.00
# 6882945                                      1.00
# 6882946                                      2.00
# 6882947                                      1.00
#        retail_and_recreation_percent_change_from_baseline  \
# count                                             789.00
# mean                                              -10.33
# std                                                14.28
# min                                               -55.00
# 25%                                               -18.00
# 50%                                                -8.00
# 75%                                                -1.00
# max                                                24.00
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# count                                             789.00
# mean                                                9.81
# std                                                12.90
# min                                               -27.00
# 25%                                                 1.00
# 50%                                                 7.00
# 75%                                                20.00
# max                                                59.00
#
#        parks_percent_change_from_baseline  \
# count                              789.00
# mean                               -25.02
# std                                 14.83
# min                                -58.00
# 25%                                -36.00
# 50%                                -24.00
# 75%                                -16.00
# max                                 49.00
#
#        transit_stations_percent_change_from_baseline  \
# count                                         789.00
# mean                                          -37.61
# std                                            13.91
# min                                           -69.00
# 25%                                           -50.00
# 50%                                           -35.00
# 75%                                           -27.00
# max                                            -2.00
#
#        workplaces_percent_change_from_baseline  \
# count                                   789.00
# mean                                    -13.99
# std                                      12.63
# min                                     -70.00
# 25%                                     -20.00
# 50%                                     -12.00
# 75%                                      -6.00
# max                                      11.00
#
#        residential_percent_change_from_baseline
# count                                    789.00
# mean                                       5.26
# std                                        5.30
# min                                       -5.00
# 25%                                        1.00
# 50%                                        4.00
# 75%                                        9.00
# max                                       23.00

# %%
print(df_th_cov.shape)
display (df_th_cov.head())
display (df_th_cov.describe())
# Out:
# (833, 7)
#        continent  location       date  new_cases  new_deaths  \
# 159254      Asia  Thailand 2020-01-04       0.00        0.00
# 159255      Asia  Thailand 2020-01-05       0.00        0.00
# 159256      Asia  Thailand 2020-01-06       0.00        0.00
# 159257      Asia  Thailand 2020-01-07       0.00        0.00
# 159258      Asia  Thailand 2020-01-08       0.00        0.00
#
#         people_vaccinated  people_fully_vaccinated
# 159254               0.00                     0.00
# 159255               0.00                     0.00
# 159256               0.00                     0.00
# 159257               0.00                     0.00
# 159258               0.00                     0.00
#        new_cases  new_deaths  people_vaccinated  people_fully_vaccinated
# count     833.00      833.00             833.00                   833.00
# mean    4,816.56       32.12      13,297,164.20            10,588,934.72
# std     7,880.19       57.59      20,689,560.00            18,330,479.88
# min         0.00        0.00               0.00                     0.00
# 25%         5.00        0.00               0.00                     0.00
# 50%       175.00        1.00               0.00                     0.00
# 75%     7,574.00       38.00      24,918,054.00             9,698,842.00
# max    52,284.00      312.00      55,849,949.00            50,520,022.00

# %%
## Create dates to join
##df_th_mob.to_csv('df_th_mob.csv') to check data format
###df_th_cov.to_csv('df_th_cov.csv')
df_th_cov['date'] = pd.to_datetime(df_th_cov['date'], format='%y%m%d')
#df['Dates'] = pd.to_datetime(df['Dates'], format='%y%m%d')
print(df_th_cov.columns)
#change data type
# Out:
# Index(['continent', 'location', 'date', 'new_cases', 'new_deaths',
#        'people_vaccinated', 'people_fully_vaccinated'],
#       dtype='object')

# %%
df_th_cov.head()
# Out:
#        continent  location       date  new_cases  new_deaths  \
# 159254      Asia  Thailand 2020-01-04       0.00        0.00
# 159255      Asia  Thailand 2020-01-05       0.00        0.00
# 159256      Asia  Thailand 2020-01-06       0.00        0.00
# 159257      Asia  Thailand 2020-01-07       0.00        0.00
# 159258      Asia  Thailand 2020-01-08       0.00        0.00
#
#         people_vaccinated  people_fully_vaccinated
# 159254               0.00                     0.00
# 159255               0.00                     0.00
# 159256               0.00                     0.00
# 159257               0.00                     0.00
# 159258               0.00                     0.00

# %%
#dates and string dates for df cov th
df_th_cov['Year'] = df_th_cov['date'].dt.year
df_th_cov['Month'] = df_th_cov['date'].dt.month
df_th_cov['Month_Year'] = pd.to_datetime(df_th_cov['date'], format='%Y%m%d').dt.strftime('%b-%Y')
df_th_cov['M_Year'] = pd.to_datetime(df_th_cov['date'], format='%Y%m%d').dt.strftime('%m-%Y')
df_th_cov['Week'] = pd.to_datetime(df_th_cov['date'], format='%Y%m%d').dt.isocalendar().week
df_th_cov[['Year', 'Month','Month_Year', 'M_Year', 'Week']] = df_th_cov[['Year', 'Month','Month_Year', 'M_Year', 'Week']].astype(str)
df_th_cov['Week-Year'] = (df_th_cov['Week']+'-'+df_th_cov['Year']).astype(str)
df_th_cov = df_th_cov[['Year', 'Month','Month_Year', 'M_Year', 'Week', 
             'Week-Year','continent', 'location', 'date', 'new_cases', 
             'new_deaths','people_vaccinated', 'people_fully_vaccinated']]
display(df_th_cov.head())
# Out:
#         Year Month Month_Year   M_Year Week Week-Year continent  location  \
# 159254  2020     1   Jan-2020  01-2020    1    1-2020      Asia  Thailand
# 159255  2020     1   Jan-2020  01-2020    1    1-2020      Asia  Thailand
# 159256  2020     1   Jan-2020  01-2020    2    2-2020      Asia  Thailand
# 159257  2020     1   Jan-2020  01-2020    2    2-2020      Asia  Thailand
# 159258  2020     1   Jan-2020  01-2020    2    2-2020      Asia  Thailand
#
#              date  new_cases  new_deaths  people_vaccinated  \
# 159254 2020-01-04       0.00        0.00               0.00
# 159255 2020-01-05       0.00        0.00               0.00
# 159256 2020-01-06       0.00        0.00               0.00
# 159257 2020-01-07       0.00        0.00               0.00
# 159258 2020-01-08       0.00        0.00               0.00
#
#         people_fully_vaccinated
# 159254                     0.00
# 159255                     0.00
# 159256                     0.00
# 159257                     0.00
# 159258                     0.00

# %%
df_th_mob['Year'] = df_th_mob['date'].dt.year
df_th_mob['Month'] = df_th_mob['date'].dt.month
df_th_mob['Month_Year'] = pd.to_datetime(df_th_mob['date'], format='%Y%m%d').dt.strftime('%b-%Y')
df_th_mob['M_Year'] = pd.to_datetime(df_th_mob['date'], format='%Y%m%d').dt.strftime('%m-%Y')
df_th_mob['Week'] = pd.to_datetime(df_th_mob['date'], format='%Y%m%d').dt.isocalendar().week
df_th_mob[['Year', 'Month','Month_Year', 'M_Year', 'Week']] = df_th_mob[['Year', 'Month','Month_Year', 'M_Year', 'Week']].astype(str)
df_th_mob['Week-Year'] = (df_th_mob['Week']+'-'+df_th_mob['Year']).astype(str)
df_th_mob = df_th_mob[['Year', 'Month','Month_Year', 'M_Year', 'Week', 
             'Week-Year','country_region_code', 'country_region', 'date','retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline']]
display(df_th_mob.head())
# Out:
#          Year Month Month_Year   M_Year Week Week-Year country_region_code  \
# 6882943  2020     2   Feb-2020  02-2020    7    7-2020                  TH
# 6882944  2020     2   Feb-2020  02-2020    7    7-2020                  TH
# 6882945  2020     2   Feb-2020  02-2020    8    8-2020                  TH
# 6882946  2020     2   Feb-2020  02-2020    8    8-2020                  TH
# 6882947  2020     2   Feb-2020  02-2020    8    8-2020                  TH
#
#         country_region       date  \
# 6882943       Thailand 2020-02-15
# 6882944       Thailand 2020-02-16
# 6882945       Thailand 2020-02-17
# 6882946       Thailand 2020-02-18
# 6882947       Thailand 2020-02-19
#
#          retail_and_recreation_percent_change_from_baseline  \
# 6882943                                              -3.00
# 6882944                                              -3.00
# 6882945                                              -3.00
# 6882946                                              -3.00
# 6882947                                              -4.00
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 6882943                                               1.00
# 6882944                                               2.00
# 6882945                                               1.00
# 6882946                                               0.00
# 6882947                                              -3.00
#
#          parks_percent_change_from_baseline  \
# 6882943                               -8.00
# 6882944                               -5.00
# 6882945                               -3.00
# 6882946                               -5.00
# 6882947                               -3.00
#
#          transit_stations_percent_change_from_baseline  \
# 6882943                                          -2.00
# 6882944                                          -4.00
# 6882945                                          -4.00
# 6882946                                          -6.00
# 6882947                                          -6.00
#
#          workplaces_percent_change_from_baseline  \
# 6882943                                     7.00
# 6882944                                     2.00
# 6882945                                     2.00
# 6882946                                     0.00
# 6882947                                     0.00
#
#          residential_percent_change_from_baseline
# 6882943                                      1.00
# 6882944                                      2.00
# 6882945                                      1.00
# 6882946                                      2.00
# 6882947                                      1.00

# %%
## create metrics for the data 
df_th_mob['Total_Mobility'] = df_th_mob[['retail_and_recreation_percent_change_from_baseline','grocery_and_pharmacy_percent_change_from_baseline',
                                       'parks_percent_change_from_baseline','transit_stations_percent_change_from_baseline','workplaces_percent_change_from_baseline']].mean(axis=1)
df_th_mob['No_Mobility'] = df_th_mob[['residential_percent_change_from_baseline']]
df_th_mob.head()
# Out:
#          Year Month Month_Year   M_Year Week Week-Year country_region_code  \
# 6882943  2020     2   Feb-2020  02-2020    7    7-2020                  TH
# 6882944  2020     2   Feb-2020  02-2020    7    7-2020                  TH
# 6882945  2020     2   Feb-2020  02-2020    8    8-2020                  TH
# 6882946  2020     2   Feb-2020  02-2020    8    8-2020                  TH
# 6882947  2020     2   Feb-2020  02-2020    8    8-2020                  TH
#
#         country_region       date  \
# 6882943       Thailand 2020-02-15
# 6882944       Thailand 2020-02-16
# 6882945       Thailand 2020-02-17
# 6882946       Thailand 2020-02-18
# 6882947       Thailand 2020-02-19
#
#          retail_and_recreation_percent_change_from_baseline  \
# 6882943                                              -3.00
# 6882944                                              -3.00
# 6882945                                              -3.00
# 6882946                                              -3.00
# 6882947                                              -4.00
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 6882943                                               1.00
# 6882944                                               2.00
# 6882945                                               1.00
# 6882946                                               0.00
# 6882947                                              -3.00
#
#          parks_percent_change_from_baseline  \
# 6882943                               -8.00
# 6882944                               -5.00
# 6882945                               -3.00
# 6882946                               -5.00
# 6882947                               -3.00
#
#          transit_stations_percent_change_from_baseline  \
# 6882943                                          -2.00
# 6882944                                          -4.00
# 6882945                                          -4.00
# 6882946                                          -6.00
# 6882947                                          -6.00
#
#          workplaces_percent_change_from_baseline  \
# 6882943                                     7.00
# 6882944                                     2.00
# 6882945                                     2.00
# 6882946                                     0.00
# 6882947                                     0.00
#
#          residential_percent_change_from_baseline  Total_Mobility  No_Mobility
# 6882943                                      1.00           -1.00         1.00
# 6882944                                      2.00           -1.60         2.00
# 6882945                                      1.00           -1.40         1.00
# 6882946                                      2.00           -2.80         2.00
# 6882947                                      1.00           -3.20         1.00

# %%
#df_th_cov = df_th_cov [(df_th_cov['date'] > '2020-04-01') & (df_th_cov['date'] < '2021-12-31')]

# %%
df_th_mob.head()
# Out:
#          Year Month Month_Year   M_Year Week Week-Year country_region_code  \
# 6882943  2020     2   Feb-2020  02-2020    7    7-2020                  TH
# 6882944  2020     2   Feb-2020  02-2020    7    7-2020                  TH
# 6882945  2020     2   Feb-2020  02-2020    8    8-2020                  TH
# 6882946  2020     2   Feb-2020  02-2020    8    8-2020                  TH
# 6882947  2020     2   Feb-2020  02-2020    8    8-2020                  TH
#
#         country_region       date  \
# 6882943       Thailand 2020-02-15
# 6882944       Thailand 2020-02-16
# 6882945       Thailand 2020-02-17
# 6882946       Thailand 2020-02-18
# 6882947       Thailand 2020-02-19
#
#          retail_and_recreation_percent_change_from_baseline  \
# 6882943                                              -3.00
# 6882944                                              -3.00
# 6882945                                              -3.00
# 6882946                                              -3.00
# 6882947                                              -4.00
#
#          grocery_and_pharmacy_percent_change_from_baseline  \
# 6882943                                               1.00
# 6882944                                               2.00
# 6882945                                               1.00
# 6882946                                               0.00
# 6882947                                              -3.00
#
#          parks_percent_change_from_baseline  \
# 6882943                               -8.00
# 6882944                               -5.00
# 6882945                               -3.00
# 6882946                               -5.00
# 6882947                               -3.00
#
#          transit_stations_percent_change_from_baseline  \
# 6882943                                          -2.00
# 6882944                                          -4.00
# 6882945                                          -4.00
# 6882946                                          -6.00
# 6882947                                          -6.00
#
#          workplaces_percent_change_from_baseline  \
# 6882943                                     7.00
# 6882944                                     2.00
# 6882945                                     2.00
# 6882946                                     0.00
# 6882947                                     0.00
#
#          residential_percent_change_from_baseline  Total_Mobility  No_Mobility
# 6882943                                      1.00           -1.00         1.00
# 6882944                                      2.00           -1.60         2.00
# 6882945                                      1.00           -1.40         1.00
# 6882946                                      2.00           -2.80         2.00
# 6882947                                      1.00           -3.20         1.00

# %% [markdown]
# ## Weekly Aggregation of Data in Both Mobility and Covid Files

# %%
df_daily = df_th_cov.merge(df_th_mob, how ='left',on='date')
df_daily.head()
df_daily.columns
df_daily.head()
# Out:
#   Year_x Month_x Month_Year_x M_Year_x Week_x Week-Year_x continent  location  \
# 0   2020       1     Jan-2020  01-2020      1      1-2020      Asia  Thailand
# 1   2020       1     Jan-2020  01-2020      1      1-2020      Asia  Thailand
# 2   2020       1     Jan-2020  01-2020      2      2-2020      Asia  Thailand
# 3   2020       1     Jan-2020  01-2020      2      2-2020      Asia  Thailand
# 4   2020       1     Jan-2020  01-2020      2      2-2020      Asia  Thailand
#
#         date  new_cases  ...  country_region_code  country_region  \
# 0 2020-01-04       0.00  ...                  NaN             NaN
# 1 2020-01-05       0.00  ...                  NaN             NaN
# 2 2020-01-06       0.00  ...                  NaN             NaN
# 3 2020-01-07       0.00  ...                  NaN             NaN
# 4 2020-01-08       0.00  ...                  NaN             NaN
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   parks_percent_change_from_baseline  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
#
#   transit_stations_percent_change_from_baseline  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   workplaces_percent_change_from_baseline  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   residential_percent_change_from_baseline Total_Mobility No_Mobility
# 0                                      NaN            NaN         NaN
# 1                                      NaN            NaN         NaN
# 2                                      NaN            NaN         NaN
# 3                                      NaN            NaN         NaN
# 4                                      NaN            NaN         NaN
#
# [5 rows x 29 columns]

# %%
df_daily.head()
# Out:
#   Year_x Month_x Month_Year_x M_Year_x Week_x Week-Year_x continent  location  \
# 0   2020       1     Jan-2020  01-2020      1      1-2020      Asia  Thailand
# 1   2020       1     Jan-2020  01-2020      1      1-2020      Asia  Thailand
# 2   2020       1     Jan-2020  01-2020      2      2-2020      Asia  Thailand
# 3   2020       1     Jan-2020  01-2020      2      2-2020      Asia  Thailand
# 4   2020       1     Jan-2020  01-2020      2      2-2020      Asia  Thailand
#
#         date  new_cases  ...  people_vaccinated  people_fully_vaccinated  \
# 0 2020-01-04       0.00  ...               0.00                     0.00
# 1 2020-01-05       0.00  ...               0.00                     0.00
# 2 2020-01-06       0.00  ...               0.00                     0.00
# 3 2020-01-07       0.00  ...               0.00                     0.00
# 4 2020-01-08       0.00  ...               0.00                     0.00
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    parks_percent_change_from_baseline  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    workplaces_percent_change_from_baseline  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    residential_percent_change_from_baseline  Total_Mobility  No_Mobility
# 0                                       NaN             NaN          NaN
# 1                                       NaN             NaN          NaN
# 2                                       NaN             NaN          NaN
# 3                                       NaN             NaN          NaN
# 4                                       NaN             NaN          NaN
#
# [5 rows x 21 columns]

# %%
df_daily=df_daily.loc[:,['Year_x', 'Month_x', 'Month_Year_x', 'M_Year_x', 'Week_x',
       'Week-Year_x', 'continent', 'location', 'date', 'new_cases',
       'new_deaths', 'people_vaccinated', 'people_fully_vaccinated','retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline', 'Total_Mobility',
       'No_Mobility']]
df_daily.rename(columns={'Year_x': 'Year', 'Month_x': 'Month','Month_Year_x':'Month_Year','M_Year_x':'M_Year','Week_x':'Week','Week-Year_x':'Week-Year'})
# Out:
#      Year Month Month_Year   M_Year Week Week-Year continent  location  \
# 0    2020     1   Jan-2020  01-2020    1    1-2020      Asia  Thailand
# 1    2020     1   Jan-2020  01-2020    1    1-2020      Asia  Thailand
# 2    2020     1   Jan-2020  01-2020    2    2-2020      Asia  Thailand
# 3    2020     1   Jan-2020  01-2020    2    2-2020      Asia  Thailand
# 4    2020     1   Jan-2020  01-2020    2    2-2020      Asia  Thailand
# ..    ...   ...        ...      ...  ...       ...       ...       ...
# 828  2022     4   Apr-2022  04-2022   15   15-2022      Asia  Thailand
# 829  2022     4   Apr-2022  04-2022   15   15-2022      Asia  Thailand
# 830  2022     4   Apr-2022  04-2022   15   15-2022      Asia  Thailand
# 831  2022     4   Apr-2022  04-2022   15   15-2022      Asia  Thailand
# 832  2022     4   Apr-2022  04-2022   15   15-2022      Asia  Thailand
#
#           date  new_cases  ...  people_vaccinated  people_fully_vaccinated  \
# 0   2020-01-04       0.00  ...               0.00                     0.00
# 1   2020-01-05       0.00  ...               0.00                     0.00
# 2   2020-01-06       0.00  ...               0.00                     0.00
# 3   2020-01-07       0.00  ...               0.00                     0.00
# 4   2020-01-08       0.00  ...               0.00                     0.00
# ..         ...        ...  ...                ...                      ...
# 828 2022-04-11  19,982.00  ...      55,829,715.00            50,494,875.00
# 829 2022-04-12       0.00  ...      55,847,558.00            50,518,220.00
# 830 2022-04-13  47,149.00  ...      55,848,828.00            50,519,218.00
# 831 2022-04-14  20,289.00  ...      55,849,949.00            50,520,022.00
# 832 2022-04-15  18,892.00  ...               0.00                     0.00
#
#      retail_and_recreation_percent_change_from_baseline  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 828                                               2.00
# 829                                               6.00
# 830                                               3.00
# 831                                                NaN
# 832                                                NaN
#
#      grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 828                                              28.00
# 829                                              35.00
# 830                                              32.00
# 831                                                NaN
# 832                                                NaN
#
#      parks_percent_change_from_baseline  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# ..                                  ...
# 828                               11.00
# 829                               20.00
# 830                               48.00
# 831                                 NaN
# 832                                 NaN
#
#      transit_stations_percent_change_from_baseline  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ..                                             ...
# 828                                         -29.00
# 829                                         -26.00
# 830                                         -33.00
# 831                                            NaN
# 832                                            NaN
#
#      workplaces_percent_change_from_baseline  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# ..                                       ...
# 828                                   -23.00
# 829                                   -30.00
# 830                                   -64.00
# 831                                      NaN
# 832                                      NaN
#
#      residential_percent_change_from_baseline  Total_Mobility  No_Mobility
# 0                                         NaN             NaN          NaN
# 1                                         NaN             NaN          NaN
# 2                                         NaN             NaN          NaN
# 3                                         NaN             NaN          NaN
# 4                                         NaN             NaN          NaN
# ..                                        ...             ...          ...
# 828                                     11.00           -2.20        11.00
# 829                                     11.00            1.00        11.00
# 830                                     16.00           -2.80        16.00
# 831                                       NaN             NaN          NaN
# 832                                       NaN             NaN          NaN
#
# [833 rows x 21 columns]

# %%
df_daily.columns
df_cov_daily = df_th_cov[['Year', 'Month', 'Month_Year', 'M_Year', 'Week', 'Week-Year',
       'continent', 'location', 'date', 'new_cases', 'new_deaths']]
df_cov_daily = pd.melt(df_cov_daily, id_vars =['Year', 'Month', 'Month_Year', 'M_Year', 'Week', 'Week-Year',
       'continent', 'location', 'date'], value_vars =['new_cases', 'new_deaths'])

# %%
df_daily = df_daily[['date', 'new_cases',
       'new_deaths', 'people_vaccinated', 'people_fully_vaccinated',
       'retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline', 'Total_Mobility',
       'No_Mobility']]
df_daily[['new_cases',
       'new_deaths', 'people_vaccinated', 'people_fully_vaccinated',
       'retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline', 'Total_Mobility',
       'No_Mobility']] = df_daily[['new_cases',
       'new_deaths', 'people_vaccinated', 'people_fully_vaccinated',
       'retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline', 'Total_Mobility',
       'No_Mobility']].fillna(value=0)

df_daily.head()
# Out:
#         date  new_cases  new_deaths  people_vaccinated  \
# 0 2020-01-04       0.00        0.00               0.00
# 1 2020-01-05       0.00        0.00               0.00
# 2 2020-01-06       0.00        0.00               0.00
# 3 2020-01-07       0.00        0.00               0.00
# 4 2020-01-08       0.00        0.00               0.00
#
#    people_fully_vaccinated  \
# 0                     0.00
# 1                     0.00
# 2                     0.00
# 3                     0.00
# 4                     0.00
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
# 3                                               0.00
# 4                                               0.00
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
# 3                                               0.00
# 4                                               0.00
#
#    parks_percent_change_from_baseline  \
# 0                                0.00
# 1                                0.00
# 2                                0.00
# 3                                0.00
# 4                                0.00
#
#    transit_stations_percent_change_from_baseline  \
# 0                                           0.00
# 1                                           0.00
# 2                                           0.00
# 3                                           0.00
# 4                                           0.00
#
#    workplaces_percent_change_from_baseline  \
# 0                                     0.00
# 1                                     0.00
# 2                                     0.00
# 3                                     0.00
# 4                                     0.00
#
#    residential_percent_change_from_baseline  Total_Mobility  No_Mobility
# 0                                      0.00            0.00         0.00
# 1                                      0.00            0.00         0.00
# 2                                      0.00            0.00         0.00
# 3                                      0.00            0.00         0.00
# 4                                      0.00            0.00         0.00

# %%
df_daily['date'] = pd.to_datetime(df_daily['date'], errors='coerce')

# %%
df_daily['date'] = pd.to_datetime(df_daily['date'], format='%Y-%m-%d', errors='coerce').ffill()

# %%
df_daily.head()

df_daily['Week_Number'] = df_daily['date'].dt.isocalendar().week 
# Getting year. Weeknum is common across years to we need to create unique index by using year and weeknum
df_daily['Year'] = df_daily['date'].dt.year

# Grouping based on required values
df2 = df_daily.groupby(['Year','Week_Number']).agg({'date':'min','new_cases':'sum', 
                                              'new_deaths':'sum', 
                                              'people_vaccinated':'max', 
                                              'people_fully_vaccinated':'max',
                                              'retail_and_recreation_percent_change_from_baseline':'mean',
                                             'grocery_and_pharmacy_percent_change_from_baseline':'mean',
                                             'parks_percent_change_from_baseline':'mean',
                                             'transit_stations_percent_change_from_baseline':'mean',
                                             'workplaces_percent_change_from_baseline':'mean',
                                             'residential_percent_change_from_baseline':'mean',
                                             'Total_Mobility':'mean',
                                             'No_Mobility':'mean'})

df2 = df2.reset_index()

# %%
display(df2.head())
display(df2.dtypes)

df_weekly.to_csv('df2weekly.csv')
# Out:
#    Year  Week_Number       date  new_cases  new_deaths  people_vaccinated  \
# 0  2020            1 2020-01-04       0.00        0.00               0.00
# 1  2020            2 2020-01-06       0.00        0.00               0.00
# 2  2020            3 2020-01-13       0.00        0.00               0.00
# 3  2020            4 2020-01-20       4.00        0.00               0.00
# 4  2020            5 2020-01-27      11.00        0.00               0.00
#
#    people_fully_vaccinated  \
# 0                     0.00
# 1                     0.00
# 2                     0.00
# 3                     0.00
# 4                     0.00
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
# 3                                               0.00
# 4                                               0.00
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                               0.00
# 1                                               0.00
# 2                                               0.00
# 3                                               0.00
# 4                                               0.00
#
#    parks_percent_change_from_baseline  \
# 0                                0.00
# 1                                0.00
# 2                                0.00
# 3                                0.00
# 4                                0.00
#
#    transit_stations_percent_change_from_baseline  \
# 0                                           0.00
# 1                                           0.00
# 2                                           0.00
# 3                                           0.00
# 4                                           0.00
#
#    workplaces_percent_change_from_baseline  \
# 0                                     0.00
# 1                                     0.00
# 2                                     0.00
# 3                                     0.00
# 4                                     0.00
#
#    residential_percent_change_from_baseline  Total_Mobility  No_Mobility
# 0                                      0.00            0.00         0.00
# 1                                      0.00            0.00         0.00
# 2                                      0.00            0.00         0.00
# 3                                      0.00            0.00         0.00
# 4                                      0.00            0.00         0.00
# Year                                                           int64
# Week_Number                                                    int64
# date                                                  datetime64[ns]
# new_cases                                                    float64
# new_deaths                                                   float64
# people_vaccinated                                            float64
# people_fully_vaccinated                                      float64
# retail_and_recreation_percent_change_from_baseline           float64
# grocery_and_pharmacy_percent_change_from_baseline            float64
# parks_percent_change_from_baseline                           float64
# transit_stations_percent_change_from_baseline                float64
# workplaces_percent_change_from_baseline                      float64
# residential_percent_change_from_baseline                     float64
# Total_Mobility                                               float64
# No_Mobility                                                  float64
# dtype: object
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_40140/4049589548.py in <module>
#       2 display(df2.dtypes)
#       3
# ----> 4 df_weekly.to_csv('df2weekly.csv')
#
# NameError: name 'df_weekly' is not defined

# %%
#unstandardized
df_weekly = df2
df_anova = df_weekly[['date','Week_Number','Year','Total_Mobility']]
L1_start='2020-04-01'
L1_end ='2020-07-31'
L2_start='2021-04-07'
L2_end ='2021-07-31'
df_anova_l1 = df_weekly.loc[(df_weekly['date']>=L1_start)&(df_weekly['date']<=L1_end)]
df_anova_L2 = df_weekly.loc[(df_weekly['date']>=L2_start)&(df_weekly['date']<=L2_end)]
df_anova_l1['Lockdown'] = 'Lockdown 2020'
df_anova_L2['Lockdown'] = 'Lockdown 2021'
df_anova_fi = df_anova_l1.append(df_anova_L2, ignore_index=False, verify_integrity=False, sort=False)
df_anova_fi['Month_Name'] = pd.to_datetime(df_anova_fi['date'], format='%Y%m%d').dt.strftime('%b')

df_anova_fi.head()

df_anova_fi = df_anova_fi[['Year', 'Week_Number','Month_Name','Lockdown','Total_Mobility','new_cases']]
df_anova_fi['Year'] = df_anova_fi['Year'].astype(str)
df_anova_fi['Week_Number'] = 'W' + df_anova_fi['Week_Number'].astype(str)
df_anova_fi
# Out:
#     Year Week_Number Month_Name       Lockdown  Total_Mobility  new_cases
# 14  2020         W15        Apr  Lockdown 2020          -42.23     382.00
# 15  2020         W16        Apr  Lockdown 2020          -41.74     214.00
# 16  2020         W17        Apr  Lockdown 2020          -39.97     157.00
# 17  2020         W18        Apr  Lockdown 2020          -35.57      47.00
# 18  2020         W19        May  Lockdown 2020          -31.43      40.00
# 19  2020         W20        May  Lockdown 2020          -27.94      19.00
# 20  2020         W21        May  Lockdown 2020          -24.60      12.00
# 21  2020         W22        May  Lockdown 2020          -22.17      41.00
# 22  2020         W23        Jun  Lockdown 2020          -19.94      31.00
# 23  2020         W24        Jun  Lockdown 2020          -18.09      23.00
# 24  2020         W25        Jun  Lockdown 2020          -17.11      13.00
# 25  2020         W26        Jun  Lockdown 2020          -14.60      14.00
# 26  2020         W27        Jun  Lockdown 2020           -9.51      28.00
# 27  2020         W28        Jul  Lockdown 2020          -12.23      27.00
# 28  2020         W29        Jul  Lockdown 2020          -12.37      32.00
# 29  2020         W30        Jul  Lockdown 2020           -9.34      60.00
# 30  2020         W31        Jul  Lockdown 2020          -10.00      26.00
# 67  2021         W15        Apr  Lockdown 2021          -23.63   9,727.00
# 68  2021         W16        Apr  Lockdown 2021          -24.74  13,108.00
# 69  2021         W17        Apr  Lockdown 2021          -30.03  13,524.00
# 70  2021         W18        May  Lockdown 2021          -30.89  14,391.00
# 71  2021         W19        May  Lockdown 2021          -29.46  18,072.00
# 72  2021         W20        May  Lockdown 2021          -24.37  28,053.00
# 73  2021         W21        May  Lockdown 2021          -18.40  24,807.00
# 74  2021         W22        May  Lockdown 2021          -15.43  23,160.00
# 75  2021         W23        Jun  Lockdown 2021          -18.46  18,442.00
# 76  2021         W24        Jun  Lockdown 2021          -19.29  22,222.00
# 77  2021         W25        Jun  Lockdown 2021          -20.74  26,316.00
# 78  2021         W26        Jun  Lockdown 2021          -19.31  38,620.00
# 79  2021         W27        Jul  Lockdown 2021          -19.74  53,304.00
# 80  2021         W28        Jul  Lockdown 2021          -23.60  67,015.00
# 81  2021         W29        Jul  Lockdown 2021          -28.57  93,916.00
# 82  2021         W30        Jul  Lockdown 2021          -30.29 118,012.00

# %%
df_weekly = df_weekly[['date','new_cases','new_deaths','people_vaccinated','Total_Mobility']]
df_weekly.describe()
# Out:
#        new_cases  new_deaths  people_vaccinated  Total_Mobility
# count     122.00      122.00             122.00          122.00
# mean   32,886.87      219.31      14,103,516.40          -14.45
# std    50,436.19      388.85      21,174,535.08           10.59
# min         0.00        0.00               0.00          -42.23
# 25%        40.25        0.00               0.00          -21.81
# 50%     1,217.00        4.00               0.00          -12.60
# 75%    53,284.25      267.00      28,468,471.50           -6.15
# max   182,767.00    1,823.00      55,849,949.00            5.04

# %%
df_anova_fi.describe()
# Out:
#        Total_Mobility  new_cases
# count           33.00      33.00
# mean           -23.21  17,692.58
# std              8.94  28,333.64
# min            -42.23      12.00
# 25%            -29.46      31.00
# 50%            -22.17     382.00
# 75%            -18.09  23,160.00
# max             -9.34 118,012.00

# %%
import math
from numpy import inf
#df_anova_fi.replace([np.inf, -np.inf], np.nan, inplace=True)
#df_anova_fi = list(filter(lambda x: x!= inf, df_anova_fi)) 

inf = float('inf')
df_anova_fi
# Out:
#     Year Week_Number Month_Name       Lockdown  Total_Mobility  new_cases
# 14  2020         W15        Apr  Lockdown 2020          -42.23     382.00
# 15  2020         W16        Apr  Lockdown 2020          -41.74     214.00
# 16  2020         W17        Apr  Lockdown 2020          -39.97     157.00
# 17  2020         W18        Apr  Lockdown 2020          -35.57      47.00
# 18  2020         W19        May  Lockdown 2020          -31.43      40.00
# 19  2020         W20        May  Lockdown 2020          -27.94      19.00
# 20  2020         W21        May  Lockdown 2020          -24.60      12.00
# 21  2020         W22        May  Lockdown 2020          -22.17      41.00
# 22  2020         W23        Jun  Lockdown 2020          -19.94      31.00
# 23  2020         W24        Jun  Lockdown 2020          -18.09      23.00
# 24  2020         W25        Jun  Lockdown 2020          -17.11      13.00
# 25  2020         W26        Jun  Lockdown 2020          -14.60      14.00
# 26  2020         W27        Jun  Lockdown 2020           -9.51      28.00
# 27  2020         W28        Jul  Lockdown 2020          -12.23      27.00
# 28  2020         W29        Jul  Lockdown 2020          -12.37      32.00
# 29  2020         W30        Jul  Lockdown 2020           -9.34      60.00
# 30  2020         W31        Jul  Lockdown 2020          -10.00      26.00
# 67  2021         W15        Apr  Lockdown 2021          -23.63   9,727.00
# 68  2021         W16        Apr  Lockdown 2021          -24.74  13,108.00
# 69  2021         W17        Apr  Lockdown 2021          -30.03  13,524.00
# 70  2021         W18        May  Lockdown 2021          -30.89  14,391.00
# 71  2021         W19        May  Lockdown 2021          -29.46  18,072.00
# 72  2021         W20        May  Lockdown 2021          -24.37  28,053.00
# 73  2021         W21        May  Lockdown 2021          -18.40  24,807.00
# 74  2021         W22        May  Lockdown 2021          -15.43  23,160.00
# 75  2021         W23        Jun  Lockdown 2021          -18.46  18,442.00
# 76  2021         W24        Jun  Lockdown 2021          -19.29  22,222.00
# 77  2021         W25        Jun  Lockdown 2021          -20.74  26,316.00
# 78  2021         W26        Jun  Lockdown 2021          -19.31  38,620.00
# 79  2021         W27        Jul  Lockdown 2021          -19.74  53,304.00
# 80  2021         W28        Jul  Lockdown 2021          -23.60  67,015.00
# 81  2021         W29        Jul  Lockdown 2021          -28.57  93,916.00
# 82  2021         W30        Jul  Lockdown 2021          -30.29 118,012.00

# %%
# Draw Plot
fig, axes = plt.subplots(1, 2, figsize=(20,7), dpi= 80)
sns.boxplot(x='Lockdown', y='Total_Mobility', data=df_anova_fi, ax=axes[0])
sns.boxplot(x='Month_Name', y='Total_Mobility', data=df_anova_fi)

# Set Title
axes[0].set_title('Year-wise Box Plot\n(The Trend)', fontsize=18); 
axes[1].set_title('Month-wise Box Plot\n(The Seasonality)', fontsize=18)
plt.show()

# %%
import statsmodels.api as sm

from statsmodels.formula.api import ols

model = ols('Total_Mobility ~ C(Lockdown) + C(Month_Name) +\
C(Lockdown):C(Month_Name)',
            data=df_anova_fi).fit()
result = sm.stats.anova_lm(model, type=2)
display(result)
# Out:
#                              df   sum_sq  mean_sq     F  PR(>F)
# C(Lockdown)                1.00     3.87     3.87  0.23    0.64
# C(Month_Name)              3.00 1,337.38   445.79 26.20    0.00
# C(Lockdown):C(Month_Name)  3.00   788.16   262.72 15.44    0.00
# Residual                  25.00   425.36    17.01   NaN     NaN

# %%
import statsmodels.api as sm

from statsmodels.formula.api import ols
model = ols('new_cases ~ C(Lockdown) + C(Month_Name) +\
C(Lockdown):C(Month_Name)',
            data=df_anova_fi).fit()
result = sm.stats.anova_lm(model, type=2)
display(result)
# Out:
#                              df            sum_sq           mean_sq     F  \
# C(Lockdown)                1.00 10,890,585,575.01 10,890,585,575.01 95.87
# C(Month_Name)              3.00  5,879,944,189.14  1,959,981,396.38 17.25
# C(Lockdown):C(Month_Name)  3.00  6,078,970,655.75  2,026,323,551.92 17.84
# Residual                  25.00  2,839,941,030.17    113,597,641.21   NaN
#
#                            PR(>F)
# C(Lockdown)                  0.00
# C(Month_Name)                0.00
# C(Lockdown):C(Month_Name)    0.00
# Residual                      NaN

# %%
df_anova_fi.head()
# Out:
#     Year Week_Number Month_Name       Lockdown  Total_Mobility  new_cases
# 14  2020         W15        Apr  Lockdown 2020          -42.23     382.00
# 15  2020         W16        Apr  Lockdown 2020          -41.74     214.00
# 16  2020         W17        Apr  Lockdown 2020          -39.97     157.00
# 17  2020         W18        Apr  Lockdown 2020          -35.57      47.00
# 18  2020         W19        May  Lockdown 2020          -31.43      40.00

# %%
#Standardize values in each column
from sklearn.preprocessing import StandardScaler
df2_stand = StandardScaler().fit_transform(df2[['new_cases', 'new_deaths', 'people_vaccinated',
       'people_fully_vaccinated',
       'retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline', 'Total_Mobility',
       'No_Mobility']])


df2[['new_cases', 'new_deaths', 'people_vaccinated',
     'people_fully_vaccinated',
       'retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline', 'Total_Mobility',
       'No_Mobility']] = StandardScaler().fit_transform(df2[['new_cases', 'new_deaths', 'people_vaccinated',
       'people_fully_vaccinated',
       'retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline', 'Total_Mobility',
       'No_Mobility']])

# %%
df2.head()
# Out:
#    Year  Week_Number       date  new_cases  new_deaths  people_vaccinated  \
# 0  2020            1 2020-01-04      -0.65       -0.57              -0.67
# 1  2020            2 2020-01-06      -0.65       -0.57              -0.67
# 2  2020            3 2020-01-13      -0.65       -0.57              -0.67
# 3  2020            4 2020-01-20      -0.65       -0.57              -0.67
# 4  2020            5 2020-01-27      -0.65       -0.57              -0.67
#
#    people_fully_vaccinated  \
# 0                    -0.60
# 1                    -0.60
# 2                    -0.60
# 3                    -0.60
# 4                    -0.60
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                               0.70
# 1                                               0.70
# 2                                               0.70
# 3                                               0.70
# 4                                               0.70
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                              -0.76
# 1                                              -0.76
# 2                                              -0.76
# 3                                              -0.76
# 4                                              -0.76
#
#    parks_percent_change_from_baseline  \
# 0                                1.55
# 1                                1.55
# 2                                1.55
# 3                                1.55
# 4                                1.55
#
#    transit_stations_percent_change_from_baseline  \
# 0                                           2.25
# 1                                           2.25
# 2                                           2.25
# 3                                           2.25
# 4                                           2.25
#
#    workplaces_percent_change_from_baseline  \
# 0                                     1.41
# 1                                     1.41
# 2                                     1.41
# 3                                     1.41
# 4                                     1.41
#
#    residential_percent_change_from_baseline  Total_Mobility  No_Mobility
# 0                                     -0.99            1.37        -0.99
# 1                                     -0.99            1.37        -0.99
# 2                                     -0.99            1.37        -0.99
# 3                                     -0.99            1.37        -0.99
# 4                                     -0.99            1.37        -0.99

# %% [markdown]
# ### Create L2 data set weekly aggregation for Hypothesis 2 onwards

# %%
df2['date'] = pd.to_datetime(df2['date'], format='%Y%m%d', errors='raise')
start_date='2020-04-01'
end_date='2021-12-31'
mask2 = (df2['date']<='2021-12-31')
df2 = df2.loc[mask2]
df2['Year'] = df2['date'].dt.year
df2['Month'] = df2['date'].dt.month
df2['Month_Year'] = pd.to_datetime(df2['date'], format='%Y%m%d').dt.strftime('%b-%Y')
mask = (df2['date']>='2020-04-01')& (df2['date']<='2021-12-31')
df2_L2= df2.loc[mask]
df2_L2
df2_L2.to_csv('df2_Vaib.csv')
print('Done')
# Out:
# Done

# %%
df2_melt = pd.melt(df2, id_vars =['Year', 'Week_Number', 'date'], value_vars =['new_cases', 'new_deaths', 'people_vaccinated',
       'people_fully_vaccinated',
       'retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline', 'Total_Mobility',
       'No_Mobility'])

# %%
df2_melt['Month'] = df2_melt['date'].dt.month
df2_melt['Month_Year'] = pd.to_datetime(df2_melt['date'], format='%Y%m%d').dt.strftime('%b-%Y')

# %%
covlist = [['new_cases', 'new_deaths']]
cov_vac_list = [['new_cases', 'new_deaths', 'people_vaccinated',
       'people_fully_vaccinated']]

mob_cov = [['new_cases', 'new_deaths','people_fully_vaccinated','Total_Mobility','No_Mobility']]

mob_un = [['Total_Mobility',
       'No_Mobility']]

all_mob = [['retail_and_recreation_percent_change_from_baseline',
       'grocery_and_pharmacy_percent_change_from_baseline',
       'parks_percent_change_from_baseline',
       'transit_stations_percent_change_from_baseline',
       'workplaces_percent_change_from_baseline',
       'residential_percent_change_from_baseline']]

# %%
df_cov = df2_melt[df2_melt.variable.isin(['new_cases', 'new_deaths','people_vaccinated'])]

# %%
df_mob = df2_melt[df2_melt.variable.isin(['Total_Mobility','new_cases'])]

# %%
df_vac_mob = df2_melt[df2_melt.variable.isin(['Total_Mobility','people_vaccinated'])]
df_vac_mob
# Out:
#       Year  Week_Number       date           variable  value  Month Month_Year
# 212   2020            1 2020-01-04  people_vaccinated  -0.67      1   Jan-2020
# 213   2020            2 2020-01-06  people_vaccinated  -0.67      1   Jan-2020
# 214   2020            3 2020-01-13  people_vaccinated  -0.67      1   Jan-2020
# 215   2020            4 2020-01-20  people_vaccinated  -0.67      1   Jan-2020
# 216   2020            5 2020-01-27  people_vaccinated  -0.67      1   Jan-2020
# ...    ...          ...        ...                ...    ...    ...        ...
# 1161  2021           49 2021-12-06     Total_Mobility   1.16     12   Dec-2021
# 1162  2021           50 2021-12-13     Total_Mobility   1.21     12   Dec-2021
# 1163  2021           51 2021-12-20     Total_Mobility   1.34     12   Dec-2021
# 1164  2021           52 2021-12-27     Total_Mobility   1.85     12   Dec-2021
# 1165  2021           53 2021-01-01     Total_Mobility  -0.89      1   Jan-2021
#
# [212 rows x 7 columns]

# %% [markdown]
# ## Data Visualization

# %%
df2_melt.to_csv('df2_check.csv')

# %%
df2_melt['variable'].unique()
# Out:
# array(['new_cases', 'new_deaths', 'people_vaccinated',
#        'people_fully_vaccinated',
#        'retail_and_recreation_percent_change_from_baseline',
#        'grocery_and_pharmacy_percent_change_from_baseline',
#        'parks_percent_change_from_baseline',
#        'transit_stations_percent_change_from_baseline',
#        'workplaces_percent_change_from_baseline',
#        'residential_percent_change_from_baseline', 'Total_Mobility',
#        'No_Mobility'], dtype=object)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(figsize = (15, 7))
#sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_style("white")
x="date"
y="value"
# Load an example dataset with long-form data
# Plot the responses for different events and regions
sns.lineplot(x="date", y="value",hue='variable',
             data=df2_melt[df2_melt.variable.isin(['retail_and_recreation_percent_change_from_baseline', 'grocery_and_pharmacy_percent_change_from_baseline','transit_stations_percent_change_from_baseline','workplaces_percent_change_from_baseline','residential_percent_change_from_baseline','Total_Mobility'])]).set_title("Google Mobility Data in Thailand")
ax.xaxis.set_major_formatter(md.DateFormatter('%b-%Y'))
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(figsize = (15, 7))
palette = ['tab:orange', 'tab:red', 'tab:green']
#sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_style("white")
x="date"
y="value"
# Load an example dataset with long-form data
# Plot the responses for different events and regions
sns.lineplot(x="date", y="value",hue='variable',palette=palette,
             data=df2_melt[df2_melt.variable.isin(['new_cases', 'new_deaths','people_vaccinated'])]).set_title("Thailand Covid-19 New Cases, Deaths and People Vaccinated")

ax.xaxis.set_major_formatter(md.DateFormatter('%b-%Y'))
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
palette = ['tab:orange', 'tab:red', 'tab:blue']
fig, ax = plt.subplots(figsize = (15, 7))
#sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_style("white")
x="date"
y="value"
# Load an example dataset with long-form data
# Plot the responses for different events and regions
sns.lineplot(x="date", y="value",hue='variable',palette=palette,
             data=df2_melt[df2_melt.variable.isin(['new_cases', 'new_deaths','Total_Mobility'])]).set_title("Thailand Covid-19 New Cases, Deaths, and Total Mobility")
ax.xaxis.set_major_formatter(md.DateFormatter('%b-%Y'))
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
palette = ['tab:green', 'tab:blue']
fig, ax = plt.subplots(figsize = (15, 7))
#sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_style("white")
x="date"
y="value"
# Load an example dataset with long-form data
# Plot the responses for different events and regions
sns.lineplot(x="date", y="value",hue='variable',palette=palette,
             data=df2_melt[df2_melt.variable.isin(['Total_Mobility','people_vaccinated'])]).set_title("Vaccinations and Total Mobility")
ax.xaxis.set_major_formatter(md.DateFormatter('%b-%Y'))
plt.show()

# %%
df2_L2.describe()
# Out:
#           Year  Week_Number  new_cases  new_deaths  people_vaccinated  \
# count    92.00        92.00      92.00       92.00              92.00
# mean  2,020.58        29.97      -0.17        0.04              -0.22
# std       0.50        14.24       0.77        1.11               0.78
# min   2,020.00         1.00      -0.65       -0.57              -0.67
# 25%   2,020.00        19.00      -0.65       -0.57              -0.67
# 50%   2,021.00        30.50      -0.63       -0.56              -0.67
# 75%   2,021.00        42.00      -0.06        0.08              -0.14
# max   2,021.00        53.00       2.34        4.14               1.77
#
#        people_fully_vaccinated  \
# count                    92.00
# mean                     -0.26
# std                       0.70
# min                      -0.60
# 25%                      -0.60
# 50%                      -0.60
# 75%                      -0.41
# max                       1.87
#
#        retail_and_recreation_percent_change_from_baseline  \
# count                                              92.00
# mean                                               -0.13
# std                                                 1.01
# min                                                -2.84
# 25%                                                -0.71
# 50%                                                -0.06
# 75%                                                 0.48
# max                                                 2.16
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# count                                              92.00
# mean                                               -0.03
# std                                                 0.97
# min                                                -2.36
# 25%                                                -0.57
# 50%                                                -0.31
# 75%                                                 0.68
# max                                                 2.89
#
#        parks_percent_change_from_baseline  \
# count                               92.00
# mean                                -0.25
# std                                  0.89
# min                                 -1.77
# 25%                                 -0.98
# 50%                                 -0.11
# 75%                                  0.39
# max                                  2.59
#
#        transit_stations_percent_change_from_baseline  \
# count                                          92.00
# mean                                           -0.28
# std                                             0.83
# min                                            -1.77
# 25%                                            -0.99
# 50%                                            -0.07
# 75%                                             0.46
# max                                             0.99
#
#        workplaces_percent_change_from_baseline  \
# count                                    92.00
# mean                                     -0.23
# std                                       0.91
# min                                      -3.29
# 25%                                      -0.74
# 50%                                      -0.16
# 75%                                       0.39
# max                                       1.33
#
#        residential_percent_change_from_baseline  Total_Mobility  No_Mobility  \
# count                                     92.00           92.00        92.00
# mean                                       0.03           -0.24         0.03
# std                                        1.02            0.93         1.02
# min                                       -1.59           -2.64        -1.59
# 25%                                       -0.85           -0.92        -0.85
# 50%                                       -0.09           -0.11        -0.09
# 75%                                        0.67            0.41         0.67
# max                                        2.77            1.85         2.77
#
#        Month
# count  92.00
# mean    7.10
# std     3.23
# min     1.00
# 25%     5.00
# 50%     7.00
# 75%    10.00
# max    12.00

# %%
import seaborn as sns
#sns.scatterplot(x="new_cases", y="Total_Mobility", data=df2_L2)
#ax = sns.scatterplot(x="new_cases", y="Total_Mobility", data=df2_L2)
ax.set_title("New Cases and Impact on Mobility")
ax.set_xlabel("New Cases")
sns.lmplot(x="new_cases", y="Total_Mobility", data=df2_L2)
from scipy import stats
#stats.pearsonr(df2_L2['Total_Mobility'], df2_L2['new_cases'])

print('The result of Pearrson Correlation') 
display(stats.pearsonr(df2_L2['Total_Mobility'], df2_L2['new_cases']))
# Out:
# The result of Pearrson Correlation
# (-0.3105617859168812, 0.002587217044224364)

# %%
import seaborn as sns
sns.scatterplot(x="new_deaths", y="Total_Mobility", data=df2_L2)
ax = sns.scatterplot(x="new_deaths", y="Total_Mobility", data=df2_L2)
ax.set_title("New Deaths and Impact on Mobility")
ax.set_xlabel("New Deaths")
sns.lmplot(x="new_deaths", y="Total_Mobility", data=df2_L2)
from scipy import stats
stats.pearsonr(df2_L2['Total_Mobility'], df2_L2['new_deaths'])
# Out:
# (-0.3340387599050745, 0.0011371669495878894)

# %%
import seaborn as sns
sns.scatterplot(x="people_vaccinated", y="Total_Mobility", data=df2_L2)
ax = sns.scatterplot(x="people_vaccinated", y="Total_Mobility", data=df2_L2)
ax.set_title("People Vaccinated and Impact on Mobility")
ax.set_xlabel("people_vaccinated")
sns.lmplot(x="people_vaccinated", y="Total_Mobility", data=df2_L2)
from scipy import stats
stats.pearsonr(df2_L2['Total_Mobility'], df2_L2['people_vaccinated'])
# Out:
# (0.29444505238523033, 0.0043849772560203126)

# %% [markdown]
# ### First and Second Lockdown April 2020 - Jul 2020 vs. April 2021 to Jul 2021

# %%
L1_start='2020-04-01'
L1_end ='2020-07-31'
L2_start='2021-04-07'
L2_end ='2021-07-31'
dfL1 = df2.loc[(df2['date']>=L1_start)&(df2['date']<=L1_end)]
dfrealL2 = df2.loc[(df2['date']>=L2_start)&(df2['date']<=L2_end)]
dfL1['Lockdown'] = 'Lockdown 2020'
dfrealL2['Lockdown'] = 'Lockdown 2021'
dfLktotal = dfL1.append(dfrealL2, ignore_index=False, verify_integrity=False, sort=False)
dfLktotal['Month_Name'] = pd.to_datetime(dfLktotal['date'], format='%Y%m%d').dt.strftime('%b')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(figsize = (15, 7))
#sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_style("white")
x="date"
y="value"
# Load an example dataset with long-form data
# Plot the responses for different events and regions
sns.lineplot(x="Month_Name", y="Total_Mobility", hue ='Lockdown',
             data=dfLktotal).set_title("Mobility in Lockdown 1 and Lockdown 2")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(figsize = (15, 7))
#sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_style("white")
x="date"
y="value"
# Load an example dataset with long-form data
# Plot the responses for different events and regions
sns.lineplot(x="Month_Name", y="new_cases", hue ='Lockdown',
             data=dfLktotal).set_title("Covid-19 cases in Lockdown 1 and Lockdown 2")
plt.show()

# %%
from scipy.stats import shapiro

#perform Shapiro-Wilk test
shapiro(dfLktotal['Total_Mobility'])
# Out:
# ShapiroResult(statistic=0.9593103528022766, pvalue=0.24711912870407104)

# %%
from scipy.stats import shapiro

#perform Shapiro-Wilk test
shapiro(dfLktotal['new_cases'])
# Out:
# ShapiroResult(statistic=0.6767970323562622, pvalue=2.959774576538621e-07)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, ax = plt.subplots(figsize = (15, 7))
#sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.set_style("white")
x="date"
y="value"
# Load an example dataset with long-form data
# Plot the responses for different events and regions
sns.lineplot(x="Month_Name", y="new_cases", hue ='Lockdown',
             data=dfLktotal)
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
#define lag=1, 

#lag=12*(n/100)^{1/4}, n is number of observations in time series
#autolag='AIC' to let the algo define the lag automatically (will choose a the number of lags that yields the lowest AIC)
lag=9
